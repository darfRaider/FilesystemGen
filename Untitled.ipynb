# %%
import pandas as pd

# %%
df = pd.read_json('test.json').set_index('id')
df
# Out:
#     defaultSuffix filetype                                   fname  \
# id
# 0             swp  UNKNOWN            .FilesystemGenerator.cpp.swp
# 1                  UNKNOWN                              .gitignore
# 2                  UNKNOWN  018446d68ac69f6b0db8a6285d486c6d73ebda
# 3                  UNKNOWN  02a82a8ee86f45deb8d1ceb5ec4d85f5451df8
# 4                  UNKNOWN  037c7f76e83b68c04a806844ec1e340d512fb7
# ..            ...      ...                                     ...
# 185           log  UNKNOWN                                test.log
# 186                UNKNOWN                                testfile
# 187         ipynb  UNKNOWN               Untitled-checkpoint.ipynb
# 188         ipynb  UNKNOWN                          Untitled.ipynb
# 189        sample  UNKNOWN                           update.sample
#
#                           md5filehash            modified  \
# id
# 0    c1a164418a293dac9712f4c63cdc67c9 2021-08-14 13:56:53
# ...

# %%
df.groupby()
